# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # **Performing Linear Regression in Keras**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# During the pandemic, a bike-sharing service had suffered considerable losses in their revenues. As a data scientist on the analytics team, you have been tasked to help with coming up with a business plan to accelerate the company's revenue. The first step in this process is to understand the current demand for shared bikes among the people in the city.
#
# You recommend that the team first try to understand the factors on which the demand for these shared bikes depends. In this lab, we will perform a linear regression to predict the count of total rental bikes, and understand the impact of some contributing factors.
#
# <center>
#     <img src="https://live.staticflickr.com/36/84666910_b889a5ad04_b.jpg" width="300" alt="tulip flower">
# <center>

# %% [markdown]
# ## __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             <li><a href="#Defining-Helper-Functions">Defining Helper Functions</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Linear regression">Linear regression</a>
#         <ol>
#             <li><a href="#Bike-sharing-dataset">Bike sharing dataset</a></li>
#             <li><a href="#Clean-the-data">Clean the data</a></li>
#             <li><a href="#Data-exploration-:-Bivariate-analysis">Data exploration: Bivariate analysis</a></li>
#             <li><a href="#Data exploration-:-Multivariate-analysis">Data exploration: Multivariate analysis</a></li>
#             <li><a href="#Data exploration-:-Heatmap-of-columns">Data exploration: Heatmap of columns</a></li>
#             <li><a href="#Split-the-data-into-training-and-test sets">Split the data into training and test sets</a></li>
#             <li><a href="#Split-features-from-labels">Split features from labels</a></li>
#             <li><a href="#Normalization">Normalization</a></li>
#             <li><a href="#Linear-regression-with-a-single-input">Linear regression with a single input</a></li>
#             <li><a href="#Linear-regression-with-a-multiple-inputs">Linear regression with a multiple inputs</a></li>
#         </ol>
#     </li>
# </ol>
#
# <a href="#Exercises">Exercises</a>
# <ol>
#     <li><a href="#Exercise-1---Loading-a-dataset-(Auto-MPG)">Exercise 1. Loading a dataset (Auto MPG)</a></li>
#     <li><a href="#Exercise-2---Clean-the-data">Exercise 2. Clean the data</a></li>
#     <li><a href="#Exercise-3---Split-the-data">Exercise 3. Split the data</a></li>
#     <li><a href="#Exercise-4---Create-a-normalization-layer">Exercise 4. Create a normalization layer</a></li>
#     <li><a href="#Exercise-5---Linear-regression-with-multiple-inputs">Exercise 5. Linear regression with multiple inputs</a></li>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
#  - Build single-variable and multi-variable linear regression models using Keras.
#  - Use linear regression to predict a continuous target variable given a set of input features

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and machine-learning-pipeline related functions.
# *   [`seaborn`](https://seaborn.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for visualizing the data.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for additional plotting tools.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are pre-installed in the Skills Network Labs environment. However, if you run these notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda), you will need to install these libraries by removing the `#` sign before `!pip` in the following code cell.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 seaborn==0.9.0 matplotlib==3.5.0 scikit-learn==0.20.1
# Note: If your environment doesn't support "!mamba install", use "!pip install"

# %% [markdown]
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
# %%capture
# !pip install --upgrade tensorflow

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place, as follows:_

# %%
import warnings
warnings.simplefilter('ignore')

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

import numpy as np
import pandas as pd
from itertools import accumulate
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn import metrics
from sklearn.metrics import mean_squared_error

sns.set_context('notebook')
sns.set_style('white')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Linear Regression models are typically used to study the relationship between a single dependent variable $Y$ and one or more independent variable $X$.
#
# They have an easy-to-interpret mathematical formula that can generate predictions. A simple linear regression model can be used when working with one independent variable, and a multiple regression model can be used when there are more than one independent variables.
#
# We can start with a hypothesis that resembles the line, $Y=\theta_0X+\theta_1$, where $\theta_0$ and $\theta_1$ are the regression coefficients.
#
# Now how do we pick the values of ($\theta_0$) and ($\theta_1$) so that our model predictions are accurate?
#
# We use an optimization method to minimize the loss function so as to reduce the error between model predictions and the ground truth. We start by picking random values of ($\theta_0$) and ($\theta_1$), and continue to update values of the coefficients till convergence. If our loss function stops decreasing, we have reached our local minima.
#
# In multiple linear regression, we use more than one independent features ($X$) and a single dependent feature ($Y$). If we have $n$ features, our formula is as follows. Instead of considering a vector of ($m$) data entries, we will consider the ($n X m$) matrix of $X$.
#
# $Y=\theta_0+\theta_1X_1+\theta_2X_2+\theta_3X_3+...++\theta_nX_n$

# %% [markdown]
# ### Bike sharing dataset
#
# We will be using the bike-sharing dataset from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01). It contains the following features:
#
# > - instant: record index
# > - dteday : date
# > - season : season (1:winter, 2:spring, 3:summer, 4:fall)
# > - yr : year (0: 2011, 1:2012)
# > - mnth : month ( 1 to 12)
# > - hr : hour (0 to 23)
# > - holiday : weather day is holiday or not (extracted from [Web Link](https://dchr.dc.gov/page/holiday-schedules?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01))
# > - weekday : day of the week
# > - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# > - weathersit :(1) Clear, Few clouds, Partly cloudy, Partly cloudy, (2) Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist, (3) Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds, (4) Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# > - temp : Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39
# > - atemp: Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale)
# > hum: Normalized humidity. The values are divided to 100 (max)
# > windspeed: Normalized wind speed. The values are divided to 67 (max)
# > casual: count of casual users
# > registered: count of registered users
# > cnt: count of total rental bikes including both casual and registered

# %% [markdown]
# Download the dataset, and unzip the `Bike-Sharing-Dataset.zip` folder.

# %%
# import skillsnetwork
# await skillsnetwork.prepare("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/labs/Module1/L2/data/Bike-Sharing-Dataset.zip",overwrite=True)

# %% [markdown]
# We will be using the `day.csv` file.

# %%
raw_dataset = pd.read_csv('../data/bike/day.csv')

# %% [markdown]
# Let's look at some samples rows from the dataset we loaded:

# %%
raw_dataset.sample(5)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 634      635  2012-09-26       4   1     9        0        3           1
# 261      262  2011-09-19       3   0     9        0        1           1
# 280      281  2011-10-08       4   0    10        0        6           0
# 347      348  2011-12-14       4   0    12        0        3           1
# 233      234  2011-08-22       3   0     8        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 634           1  0.635000  0.596613  0.630833   0.244400     787        6946
# 261           2  0.549167  0.529675  0.690000   0.151742     691        3848
# 280           1  0.521667  0.513242  0.701250   0.045404    2235        3174
# 347           2  0.317500  0.338362  0.663750   0.060958     178        3562
# 233           1  0.691667  0.638254  0.470000   0.276750     833        3925
#
#       cnt
# 634  7733
# 261  4539
# 280  5409
# 347  3740
# 233  4758

# %% [markdown]
# ### Clean the data

# %% [markdown]
# Let us drop the `dteday` column as it is not numerical, and we already have some other date like features like `mnth`, `year` and `weekday`.
#
# We will remove `instant` as it is just a row instance identifier.
#
# We will also drop `registered` and `casual` as they are used to compute our target variable `cnt` and including them would result in data leakage.

# %%
raw_dataset = raw_dataset.drop(columns=['dteday', 'instant', 'registered', 'casual'])

# %% [markdown]
# ### Data exploration: Bivariate analysis

# %% [markdown]
# We will create scatterplots for a few numerical variables against the target variable `cnt`.

# %%
col = ['temp', 'atemp', 'hum', 'windspeed']
plt.figure(figsize=[20,12])
for i in enumerate(col):
    plt.subplot(2,2,i[0]+1)
    sns.regplot(data=raw_dataset,x=i[1],y='cnt',line_kws={"color":'red'})
    
plt.show()

# %% [markdown]
# From this, we can infer that there is a positive correlation between `temp` and `atemp` and `cnt`. There is a negative correlation between `windspeed` and `hum` and `cnt`.

# %% [markdown]
# Similarly, we can perform a bivariate analysis on the categorical variables.

# %%
col = ['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit']
plt.figure(figsize=[20,12])
for i in enumerate(col):
    plt.subplot(2,4,i[0]+1)
    sns.boxplot(data=raw_dataset,x=i[1],y='cnt')
    
plt.show()

# %% [markdown]
# From this we infer that rental bike demands are the highest during Fall and lowest during Spring. There was an increase in demand in bikes in 2019 as compared to 2018. A higher demand for bikes is observed on non-holidays as compared to holidays. Lastly, when renting bikes, clear weather is preferred over light rain, thunderstorm and snowy days.

# %% [markdown]
# ### Data exploration: Multivariate analysis

# %% [markdown]
# We can perform multivariate analysis by creating a pairplot of all the columns in our dataset.

# %%
sns.pairplot(raw_dataset)

# %% [markdown]
# ### Data exploration: Heatmap of columns

# %% [markdown]
# Using a heatmap we can explore which variables are positively or negatively correlated with one another.

# %%
plt.figure(figsize=[15,8])
fig = sns.heatmap(raw_dataset.corr(),cmap='hot_r',
            annot=True,linecolor='black',linewidths=0.01,annot_kws={"fontsize":12},fmt="0.2f")

top, bottom = fig.get_ylim()
fig.set_ylim(top+0.1,bottom-0.1)

left, right = fig.get_xlim()
fig.set_xlim(left-0.1,right+0.1) 

plt.yticks(fontsize=13,rotation=0)
plt.xticks(fontsize=13,rotation=90);

# %% [markdown]
# From the heatmap, we can infer that `temp` and `atemp` are highly correlated with each other and with `cnt`.
#
# A positive correlation between `temp`, `atemp`, `yr` and `cnt` exists, while a negative correlation between `windspeed`, `hum`, `weathersit`, `holiday` and `cnt` exists.

# %% [markdown]
# ### Split the data into training and test sets

# %% [markdown]
# Now we will split the data set into a training set and a test set. The test set will be used in the final evaluation of your models.

# %%
train_dataset = raw_dataset.sample(frac=0.8, random_state=0)
test_dataset = raw_dataset.drop(train_dataset.index)

# %% [markdown]
# ### Split features from labels

# %% [markdown]
# Separate the target value from the features. This label is the value that you will train the model to predict.

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('cnt')
test_labels = test_features.pop('cnt')

# %% [markdown]
# ### Normalization

# %% [markdown]
# Since the features in this dataset use different scales and ranges, it is generally considered good practice to normalize the features before performing linear regression. This is partly because the features are multiplied by model weights, and the scale of the outputs and gradients are impacted by that of the inputs. Even though it is possible for the model to converge without any feature normalization, the process of normalization makes the training much more stable.

# %% [markdown]
# We will use `tf.keras.layers.Normalization` as a clean and simple way to add feature normalization to our model.
#
# Let us first create a normalization layer. We will use `axis=-1` as an input argument. As per the [Keras documentation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Normalization?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01):
#
# > The axis or axes that should have a separate mean and variance for each index in the shape. For example, if shape is (None, 5) and axis=1, the layer will track 5 separate mean and variance values for the last axis. If axis is set to None, the layer will normalize all elements in the input by a scalar mean and variance. Defaults to -1, where the last axis of the input is assumed to be a feature dimension and is normalized per index.

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)

# %% [markdown]
# Now using `normalization.adapt`, we will fit the state of the pre-processing layer to the training data.
#
# This will compute the mean and variance of the data and store them as the layer's weights.

# %%
normalizer.adapt(np.array(train_features))

# %% [markdown]
# Calculate the mean and variance:

# %%
print(normalizer.mean.numpy())
print(normalizer.variance.numpy())
# Out:
# [[2.4820514  0.50598294 6.5572653  0.02735043 2.9931622  0.6803418
#   1.4        0.49609542 0.47542122 0.62892884 0.19085288]]
# [[1.2274556e+00 2.4996418e-01 1.1894585e+01 2.6602380e-02 4.0580730e+00
#   2.1747683e-01 2.9811969e-01 3.2840718e-02 2.6041929e-02 2.0187268e-02
#   6.0876710e-03]]

# %% [markdown]
# When the layer is called, it returns the input data, with each feature independently normalized. For example, let us look at the first input row:

# %%
print(np.array(train_features[:1]))
# Out:
# [[3.       0.       7.       0.       6.       0.       1.       0.686667
#   0.638263 0.585    0.208342]]

# %% [markdown]
# Now, let us look at the normalized input:

# %%
print(normalizer(np.array(train_features[:1])).numpy())
# Out:
# [[ 0.46750233 -1.0120384   0.1283716  -0.16768871  1.492623   -1.4588836
#   -0.7325962   1.0516032   1.0090884  -0.30917984  0.22415186]]

# %% [markdown]
# ### Linear regression with a single input

# %% [markdown]
# We can build a linear regression model using one or several variables.

# %% [markdown]
# Let us begin by building a single-variable linear regression to predict `'cnt'` from `'temp'`. We are using `temp` because it is highly correlated with `cnt` and should be highly predictive.
#
# We will use Keras to define a `tf.keras.Sequential` model architecture.
#
# Here are the steps we will follow to create our single-variable linear regression model:
#
# - Using the `tf.keras.layers.Normalization` preprocessing layer that we created earlier, we will normalize the `'temp'` input features.
# - Then we will apply a linear transformation to produce 1 output using a linear layer `tf.keras.layers.Dense`.
#
#
# Note that as per the documentation, the input can either be set by the `input_shape` argument, or automatically when the model is run for the first time.

# %% [markdown]
# Next, we create an array made of the `temp` features.

# %%
temp = np.array(train_features['temp'])

# %% [markdown]
# Then we will instantiate the `tf.keras.layers.Normalization` and fit its state to the data like we did before.

# %%
temp_normalizer = layers.Normalization(input_shape=[1,], axis=None)
temp_normalizer.adapt(temp)

# %% [markdown]
# Build the Keras model:

# %%
temp_model = tf.keras.Sequential([
    temp_normalizer,
    layers.Dense(units=1)
])
temp_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normalizat  (None, 1)                3
#  ion)
#
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 2
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# Now, let us configure the training procedure using `model.compile()`. Here, `loss` is used to define the loss function, which computes the quantity that a model should seek to minimize during training. And `optimizer` defines the optimizer that is used to change weights and learning rate during training to minimize losses.

# %%
temp_model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
    loss='mean_squared_error')

# %% [markdown]
# Using `keras.fit`, we train the model for 100 epochs.

# %%
# %%time
history = temp_model.fit(
    train_features['temp'],
    train_labels,
    # to view the logs, uncomment this:
    verbose=False,
    epochs=100,
    # validation split: 20% of the training data.
    validation_split = 0.2)
# Out:
# CPU times: total: 9.67 s
# Wall time: 7.56 s

# %% [markdown]
# We can create a plot of loss on the training and validation datasets over training epochs.

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.legend()
    plt.grid(True)

# %%
plot_loss(history)

# %% [markdown]
# Next, we will use `model.predict` to predict the `cnt` values in the test dataset, using just the `temp` feature values as input:

# %%
y_pred= temp_model.predict(test_features['temp'])
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# We can compute the root mean squared error:

# %%
print(np.sqrt(metrics.mean_squared_error(test_labels, y_pred)))
# Out:
# 1437.1244194393519

# %% [markdown]
# Since this a single-variable linear regression, we can easily visualize the results:

# %%
plt.figure(figsize = (4,4))
plt.plot(test_features['temp'], test_labels,'o',
         test_features['temp'],temp_model.predict(test_features['temp']),'g')
plt.show()
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# ### Linear regression with multiple inputs

# %% [markdown]
# We will create a similar setup to predict `cnt` based on multiple inputs. In this case, in our $y = mx+b$ equation, $m$ will be a matrix and $b$ will be a vector.
#
# Similar to what we did before, the Sequential model will have `normalizer` as the first layer, and `Dense` as the second layer:

# %%
linear_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1)
])

# %% [markdown]
# We will compile the model using `complie()` and train the model on 100 epochs using `fit()`:

# %%
linear_model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
    loss='mean_squared_error')

# %%
# %%time
history = linear_model.fit(
    train_features,
    train_labels,
    epochs=100,
    # to view the logs, uncomment this:
    verbose=0,
    # validation split: 20% of the training data.
    validation_split = 0.2)
# Out:
# CPU times: total: 7.78 s
# Wall time: 5.89 s

# %%
plot_loss(history)

# %% [markdown]
# We can see that with all the inputs in the regression model, it achieves a much lower training and validation error, and RMSE than the `temp_model` that had just one input.

# %%
y_pred= linear_model.predict(test_features)
print(np.sqrt(metrics.mean_squared_error(test_labels, y_pred)))
# Out:
# 5/5 [==============================] - 0s 2ms/step
# 902.169181571424

# %% [markdown]
# `get_weights` returns a list consisting of NumPy arrays. The first array gives the weights of the layer and the second array gives the biases.

# %%
# Print column names for reference
print("Column names")
print(test_features.columns)

# Print weights and biases for each layer
for layer in linear_model.layers:
    print("Layer Name:", layer.name)
    print("---")
    print("Weights")
    print("Shape:",layer.get_weights()[0].shape,'\n',layer.get_weights()[0])
    print("---")
    print("Bias")
    print("Shape:",layer.get_weights()[1].shape,'\n',layer.get_weights()[1],'\n')
# Out:
# Column names
# Index(['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed'],
#       dtype='object')
# Layer Name: normalization
# ---
# Weights
# Shape: (11,)
#  [2.4820514  0.50598294 6.5572653  0.02735043 2.9931622  0.6803418
#  1.4        0.49609542 0.47542122 0.62892884 0.19085288]
# ---
# Bias
# Shape: (11,)
#  [1.2274556e+00 2.4996418e-01 1.1894585e+01 2.6602380e-02 4.0580730e+00
#  2.1747683e-01 2.9811969e-01 3.2840718e-02 2.6041929e-02 2.0187268e-02
#  6.0876710e-03]
#
# Layer Name: dense_1
# ---
# Weights
# Shape: (11, 1)
#  [[ 362.15756 ]
#  [ 995.0367  ]
#  [  49.05925 ]
#  [-136.61966 ]
#  [ 155.86508 ]
#  [  77.322205]
#  [-357.75412 ]
#  [ 477.24472 ]
#  [ 513.9362  ]
#  [-165.33078 ]
#  [-211.42747 ]]
# ---
# Bias
# Shape: (1,)
#  [4294.2896]

# %% [markdown]
# From the model weights, we can see that, similar to what we had seen in our heatmap, `yr`, `temp` and `atemp` have the highest model weights, and hence contribute the most the `cnt` predictions.

# %% [markdown]
# ## Using Neural Networks for Linear Regression

# %% [markdown]
# In this section, we will use a Neural Network architecture in Keras to perform simple linear regression.

# %% [markdown]
# Let us begin by reading our univariate dataset. We will use the Iowa Housing dataset where the only feature is SquareFeet, and the target value is SalePrice.

# %% [markdown]
# We will reserve the last 500 data points for testing purposes.

# %%
df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/labs/Module1/L2/data/IowaHousingPrices.csv')

x_train = df[['SquareFeet']].values[1:-500]
y_train = df[['SalePrice']].values[1:-500]
x_test = df[['SquareFeet']].values[-500:]
y_test = df[['SalePrice']].values[-500:]

# %% [markdown]
# Now, we'll define the model configuration parameters. Since we're dealing with a univariate dataset, both our input and output sizes are 1. The learning rate is selected arbitrarily, where the goal is to ensure the NN doesn't overfit to the training data, and is easily generalizable to unseen test sets. We will use mean squared error as the loss function, and train the model on 30 iterations.

# %%
output_size=1
hidden_layer=500
input_size=1
learning_rate=0.51
loss_function='mean_squared_error'
epochs=30
batch_size=10

# %% [markdown]
# We will create a `Sequential` model and add a Dense layer with a relu activation in the hidden layer with ```hidden_layer``` neurons. As we have one output the output layer will have a dimension of  one.

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(hidden_layer,  activation='relu'))

model.add(keras.layers.Dense(output_size))

# %% [markdown]
# Next, we will compile and fit the model based on the configuration parameters defined earlier.

# %%
model.compile(keras.optimizers.Adam(lr=learning_rate), loss_function)

# %%
model.fit(x_train, y_train, epochs = epochs, batch_size = batch_size)
# Out:
# Epoch 1/30
# 96/96 [==============================] - 1s 3ms/step - loss: 5892586496.0000
# Epoch 2/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3754752000.0000
# Epoch 3/30
# 96/96 [==============================] - 0s 2ms/step - loss: 3739753984.0000
# Epoch 4/30
# 96/96 [==============================] - 0s 3ms/step - loss: 4148892416.0000
# Epoch 5/30
# 96/96 [==============================] - 0s 3ms/step - loss: 4025639168.0000
# Epoch 6/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3969563648.0000
# Epoch 7/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3870611712.0000
# Epoch 8/30
# 96/96 [==============================] - 0s 2ms/step - loss: 3147530496.0000
# Epoch 9/30
# 96/96 [==============================] - 0s 2ms/step - loss: 3511571200.0000
# Epoch 10/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3142903808.0000
# Epoch 11/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3448253184.0000
# Epoch 12/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3222742272.0000
# Epoch 13/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3152441600.0000
# Epoch 14/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3376756992.0000
# Epoch 15/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3312822528.0000
# Epoch 16/30
# 96/96 [==============================] - 0s 2ms/step - loss: 3200977408.0000
# Epoch 17/30
# 96/96 [==============================] - 0s 2ms/step - loss: 3236219648.0000
# Epoch 18/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3249893632.0000
# Epoch 19/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3247087872.0000
# Epoch 20/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3085898240.0000
# Epoch 21/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3238447872.0000
# Epoch 22/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3098708224.0000
# Epoch 23/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3106834176.0000
# Epoch 24/30
# 96/96 [==============================] - 0s 2ms/step - loss: 3463239936.0000
# Epoch 25/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3237453312.0000
# Epoch 26/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3104556800.0000
# Epoch 27/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3179195136.0000
# Epoch 28/30
# 96/96 [==============================] - 0s 2ms/step - loss: 3506204416.0000
# Epoch 29/30
# 96/96 [==============================] - 0s 2ms/step - loss: 3259659008.0000
# Epoch 30/30
# 96/96 [==============================] - 0s 3ms/step - loss: 3157488896.0000

# %% [markdown]
# Let us predict the sales prices on the full range of the test set and plot the result.

# %%
x=np.arange(x_test.min(),x_test.max(),10).reshape(-1,1)

# %%
y_pred = model.predict(x)
# Out:
# 17/17 [==============================] - 0s 1ms/step

# %%
plt.plot(x,y_pred,label="prediction ")
plt.plot(x_test,y_test,'ro',label="test samples")
plt.xlabel('Input')
plt.ylabel('Predicted Output')
plt.legend()
plt.show()

# %% [markdown]
# The model performs relatively well on the test set.

# %% [markdown]
# # Exercises

# %% [markdown]
# In this section, you will train a linear regression model in Keras. We will be using the classic Auto MPG dataset, and predict the fiel efficiency of automobiles.

# %% [markdown]
# ### Exercise 1 - Loading a dataset (Auto MPG)

# %% [markdown]
# The dataset is again found in the UCI Machine Learning Repository. You can download it from [here](http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01).

# %%
# Write your solution here:

url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/labs/Module1/L2/data/auto-mpg.data'
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(url, names=column_names,
                          na_values='?', comment='\t',
                          sep=' ', skipinitialspace=True)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# raw_dataset = pd.read_csv(url, names=column_names,
#                           na_values='?', comment='\t',
#                           sep=' ', skipinitialspace=True)
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2 - Clean the data

# %% [markdown]
# Drop all the rows that have NA values, and remove the `origin` column as it is categorical.

# %%
# Write your solution here
dataset = raw_dataset.dropna()
dataset = dataset.drop(labels=['Origin'], axis=1)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# dataset = raw_dataset.dropna()
# dataset = dataset.drop(columns=['Origin'])
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3 - Split the data

# %% [markdown]
# Split the data into training and test, and split the target from features.

# %%
# Write your solution here
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('MPG')
test_labels = test_features.pop('MPG')

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# train_dataset = dataset.sample(frac=0.8, random_state=0)
# test_dataset = dataset.drop(train_dataset.index)
#
# train_features = train_dataset.copy()
# test_features = test_dataset.copy()
#
# train_labels = train_features.pop('MPG')
# test_labels = test_features.pop('MPG')
# ```
#
# </details>

# %% [markdown]
# ### Exercise 4 - Create a normalization layer

# %% [markdown]
# Next, use `tf.keras.layers.Normalization` to add feature normalization to the model. Using `normalization.adapt`, fit the state of the pre-processing layer to the training data. Calculate and print the mean and variance.

# %%
# Write your solution here
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.array(train_features))

print(normalizer.mean.numpy())
print(normalizer.variance.numpy())
# Out:
# [[   5.477707  195.3185    104.869446 2990.2517     15.559236   75.898094]]
# [[2.8800766e+00 1.0850413e+04 1.4466993e+03 7.0989688e+05 7.7550278e+00
#   1.3467321e+01]]

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# normalizer = tf.keras.layers.Normalization(axis=-1)
# normalizer.adapt(np.array(train_features))
# print(normalizer.mean.numpy())
# print(normalizer.variance.numpy())
# ```
#
# </details>

# %% [markdown]
# ### Exercise 5 - Linear regression with multiple inputs

# %% [markdown]
# Create a linear regression model to predict `MPG` based on all inputs in the dataset. In this case, in our $y = mx+b$ equation, $m$ will be a matrix and $b$ will be a vector.
#
# Similar to what we did before, the Sequential model will have `normalizer` as the first layer, and `Dense` as the second layer. Compile and train the model, and plot the training history.

# %%
# Write your solution here
model = keras.Sequential()
model.add(normalizer)
model.add(keras.layers.Dense(units=1))

optimizer = keras.optimizers.Adam(learning_rate=0.004)
loss = "mean_squared_error"
model.compile(optimizer=optimizer, loss=loss)

history = model.fit(train_features, train_labels, batch_size=36, epochs=500, validation_split=0.2)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 0s 22ms/step - loss: 603.9843 - val_loss: 631.0262
# Epoch 2/500
# 7/7 [==============================] - 0s 9ms/step - loss: 600.9443 - val_loss: 627.7286
# Epoch 3/500
# 7/7 [==============================] - 0s 9ms/step - loss: 598.2176 - val_loss: 624.4018
# Epoch 4/500
# 7/7 [==============================] - 0s 9ms/step - loss: 595.2814 - val_loss: 621.2139
# Epoch 5/500
# 7/7 [==============================] - 0s 8ms/step - loss: 592.5113 - val_loss: 618.0587
# Epoch 6/500
# 7/7 [==============================] - 0s 8ms/step - loss: 589.6080 - val_loss: 615.0674
# Epoch 7/500
# 7/7 [==============================] - 0s 8ms/step - loss: 586.9659 - val_loss: 612.0620
# Epoch 8/500
# 7/7 [==============================] - 0s 15ms/step - loss: 584.3447 - val_loss: 609.0719
# Epoch 9/500
# 7/7 [==============================] - 0s 7ms/step - loss: 581.6938 - val_loss: 606.1569
# Epoch 10/500
# 7/7 [==============================] - 0s 7ms/step - loss: 579.2736 - val_loss: 603.1824
# Epoch 11/500
# 7/7 [==============================] - 0s 7ms/step - loss: 576.5851 - val_loss: 600.3654
# Epoch 12/500
# 7/7 [==============================] - 0s 7ms/step - loss: 574.1223 - val_loss: 597.5780
# Epoch 13/500
# 7/7 [==============================] - 0s 8ms/step - loss: 571.6622 - val_loss: 594.8203
# Epoch 14/500
# 7/7 [==============================] - 0s 10ms/step - loss: 569.1841 - val_loss: 592.1515
# Epoch 15/500
# 7/7 [==============================] - 0s 10ms/step - loss: 566.7505 - val_loss: 589.5729
# Epoch 16/500
# 7/7 [==============================] - 0s 7ms/step - loss: 564.4193 - val_loss: 587.0159
# Epoch 17/500
# 7/7 [==============================] - 0s 7ms/step - loss: 562.1318 - val_loss: 584.4603
# Epoch 18/500
# 7/7 [==============================] - 0s 7ms/step - loss: 560.0557 - val_loss: 581.8141
# Epoch 19/500
# 7/7 [==============================] - 0s 8ms/step - loss: 557.4653 - val_loss: 579.4891
# Epoch 20/500
# 7/7 [==============================] - 0s 7ms/step - loss: 555.3364 - val_loss: 577.1241
# Epoch 21/500
# 7/7 [==============================] - 0s 8ms/step - loss: 553.2617 - val_loss: 574.6915
# Epoch 22/500
# 7/7 [==============================] - 0s 7ms/step - loss: 551.1150 - val_loss: 572.2868
# Epoch 23/500
# 7/7 [==============================] - 0s 7ms/step - loss: 548.9865 - val_loss: 569.9420
# Epoch 24/500
# 7/7 [==============================] - 0s 8ms/step - loss: 546.7866 - val_loss: 567.7100
# Epoch 25/500
# 7/7 [==============================] - 0s 8ms/step - loss: 544.7688 - val_loss: 565.4772
# Epoch 26/500
# 7/7 [==============================] - 0s 8ms/step - loss: 542.8165 - val_loss: 563.2145
# Epoch 27/500
# 7/7 [==============================] - 0s 7ms/step - loss: 540.7673 - val_loss: 561.0338
# Epoch 28/500
# 7/7 [==============================] - 0s 7ms/step - loss: 538.7695 - val_loss: 558.9037
# Epoch 29/500
# 7/7 [==============================] - 0s 7ms/step - loss: 536.7717 - val_loss: 556.8494
# Epoch 30/500
# 7/7 [==============================] - 0s 7ms/step - loss: 534.8577 - val_loss: 554.8040
# Epoch 31/500
# 7/7 [==============================] - 0s 7ms/step - loss: 533.0511 - val_loss: 552.7049
# Epoch 32/500
# 7/7 [==============================] - 0s 7ms/step - loss: 531.0850 - val_loss: 550.7059
# Epoch 33/500
# 7/7 [==============================] - 0s 7ms/step - loss: 529.2687 - val_loss: 548.7081
# Epoch 34/500
# 7/7 [==============================] - 0s 8ms/step - loss: 527.4677 - val_loss: 546.7160
# Epoch 35/500
# 7/7 [==============================] - 0s 7ms/step - loss: 525.5708 - val_loss: 544.8304
# Epoch 36/500
# 7/7 [==============================] - 0s 7ms/step - loss: 523.8329 - val_loss: 542.9164
# Epoch 37/500
# 7/7 [==============================] - 0s 7ms/step - loss: 522.0859 - val_loss: 541.0343
# Epoch 38/500
# 7/7 [==============================] - 0s 14ms/step - loss: 520.3214 - val_loss: 539.1854
# Epoch 39/500
# 7/7 [==============================] - 0s 7ms/step - loss: 518.6047 - val_loss: 537.3480
# Epoch 40/500
# 7/7 [==============================] - 0s 7ms/step - loss: 516.9474 - val_loss: 535.5157
# Epoch 41/500
# 7/7 [==============================] - 0s 7ms/step - loss: 515.2195 - val_loss: 533.7388
# Epoch 42/500
# 7/7 [==============================] - 0s 7ms/step - loss: 513.5208 - val_loss: 532.0255
# Epoch 43/500
# 7/7 [==============================] - 0s 7ms/step - loss: 511.9380 - val_loss: 530.2745
# Epoch 44/500
# 7/7 [==============================] - 0s 7ms/step - loss: 510.2439 - val_loss: 528.6080
# Epoch 45/500
# 7/7 [==============================] - 0s 7ms/step - loss: 508.7216 - val_loss: 526.8955
# Epoch 46/500
# 7/7 [==============================] - 0s 7ms/step - loss: 507.1092 - val_loss: 525.2145
# Epoch 47/500
# 7/7 [==============================] - 0s 7ms/step - loss: 505.5427 - val_loss: 523.5290
# Epoch 48/500
# 7/7 [==============================] - 0s 7ms/step - loss: 503.9476 - val_loss: 521.9109
# Epoch 49/500
# 7/7 [==============================] - 0s 7ms/step - loss: 502.4607 - val_loss: 520.2474
# Epoch 50/500
# 7/7 [==============================] - 0s 6ms/step - loss: 500.8711 - val_loss: 518.6639
# Epoch 51/500
# 7/7 [==============================] - 0s 6ms/step - loss: 499.3396 - val_loss: 517.1046
# Epoch 52/500
# 7/7 [==============================] - 0s 6ms/step - loss: 497.8420 - val_loss: 515.5549
# Epoch 53/500
# 7/7 [==============================] - 0s 7ms/step - loss: 496.3832 - val_loss: 513.9875
# Epoch 54/500
# 7/7 [==============================] - 0s 7ms/step - loss: 494.8497 - val_loss: 512.4847
# Epoch 55/500
# 7/7 [==============================] - 0s 9ms/step - loss: 493.4476 - val_loss: 510.9447
# Epoch 56/500
# 7/7 [==============================] - 0s 8ms/step - loss: 491.9594 - val_loss: 509.4458
# Epoch 57/500
# 7/7 [==============================] - 0s 8ms/step - loss: 490.5243 - val_loss: 507.9554
# Epoch 58/500
# 7/7 [==============================] - 0s 7ms/step - loss: 489.2007 - val_loss: 506.4165
# Epoch 59/500
# 7/7 [==============================] - 0s 7ms/step - loss: 487.6556 - val_loss: 504.9828
# Epoch 60/500
# 7/7 [==============================] - 0s 7ms/step - loss: 486.2675 - val_loss: 503.5460
# Epoch 61/500
# 7/7 [==============================] - 0s 7ms/step - loss: 484.8890 - val_loss: 502.1108
# Epoch 62/500
# 7/7 [==============================] - 0s 7ms/step - loss: 483.5177 - val_loss: 500.6721
# Epoch 63/500
# 7/7 [==============================] - 0s 7ms/step - loss: 482.1554 - val_loss: 499.2382
# Epoch 64/500
# 7/7 [==============================] - 0s 7ms/step - loss: 480.7417 - val_loss: 497.8600
# Epoch 65/500
# 7/7 [==============================] - 0s 7ms/step - loss: 479.4396 - val_loss: 496.4587
# Epoch 66/500
# 7/7 [==============================] - 0s 7ms/step - loss: 478.0610 - val_loss: 495.0862
# Epoch 67/500
# 7/7 [==============================] - 0s 7ms/step - loss: 476.8221 - val_loss: 493.6608
# Epoch 68/500
# 7/7 [==============================] - 0s 16ms/step - loss: 475.3376 - val_loss: 492.3698
# Epoch 69/500
# 7/7 [==============================] - 0s 7ms/step - loss: 474.0547 - val_loss: 491.0370
# Epoch 70/500
# 7/7 [==============================] - 0s 7ms/step - loss: 472.7701 - val_loss: 489.7003
# Epoch 71/500
# 7/7 [==============================] - 0s 7ms/step - loss: 471.5130 - val_loss: 488.3198
# Epoch 72/500
# 7/7 [==============================] - 0s 7ms/step - loss: 470.1639 - val_loss: 486.9958
# Epoch 73/500
# 7/7 [==============================] - 0s 7ms/step - loss: 468.8749 - val_loss: 485.6745
# Epoch 74/500
# 7/7 [==============================] - 0s 7ms/step - loss: 467.5651 - val_loss: 484.3950
# Epoch 75/500
# 7/7 [==============================] - 0s 7ms/step - loss: 466.3138 - val_loss: 483.0910
# Epoch 76/500
# 7/7 [==============================] - 0s 7ms/step - loss: 465.0363 - val_loss: 481.8130
# Epoch 77/500
# 7/7 [==============================] - 0s 7ms/step - loss: 463.8256 - val_loss: 480.5028
# Epoch 78/500
# 7/7 [==============================] - 0s 7ms/step - loss: 462.5019 - val_loss: 479.2644
# Epoch 79/500
# 7/7 [==============================] - 0s 8ms/step - loss: 461.2971 - val_loss: 477.9763
# Epoch 80/500
# 7/7 [==============================] - 0s 8ms/step - loss: 460.0690 - val_loss: 476.6856
# Epoch 81/500
# 7/7 [==============================] - 0s 6ms/step - loss: 458.8448 - val_loss: 475.4056
# Epoch 82/500
# 7/7 [==============================] - 0s 6ms/step - loss: 457.5346 - val_loss: 474.2098
# Epoch 83/500
# 7/7 [==============================] - 0s 7ms/step - loss: 456.4061 - val_loss: 472.9291
# Epoch 84/500
# 7/7 [==============================] - 0s 6ms/step - loss: 455.1357 - val_loss: 471.6984
# Epoch 85/500
# 7/7 [==============================] - 0s 7ms/step - loss: 453.8906 - val_loss: 470.5129
# Epoch 86/500
# 7/7 [==============================] - 0s 7ms/step - loss: 452.7269 - val_loss: 469.2951
# Epoch 87/500
# 7/7 [==============================] - 0s 7ms/step - loss: 451.4905 - val_loss: 468.0787
# Epoch 88/500
# 7/7 [==============================] - 0s 8ms/step - loss: 450.3120 - val_loss: 466.8504
# Epoch 89/500
# 7/7 [==============================] - 0s 7ms/step - loss: 449.0983 - val_loss: 465.6619
# Epoch 90/500
# 7/7 [==============================] - 0s 7ms/step - loss: 447.9501 - val_loss: 464.4391
# Epoch 91/500
# 7/7 [==============================] - 0s 7ms/step - loss: 446.7479 - val_loss: 463.2367
# Epoch 92/500
# 7/7 [==============================] - 0s 9ms/step - loss: 445.5406 - val_loss: 462.0527
# Epoch 93/500
# 7/7 [==============================] - 0s 9ms/step - loss: 444.3941 - val_loss: 460.8473
# Epoch 94/500
# 7/7 [==============================] - 0s 8ms/step - loss: 443.1956 - val_loss: 459.6963
# Epoch 95/500
# 7/7 [==============================] - 0s 9ms/step - loss: 442.0642 - val_loss: 458.4951
# Epoch 96/500
# 7/7 [==============================] - 0s 12ms/step - loss: 440.8806 - val_loss: 457.3257
# Epoch 97/500
# 7/7 [==============================] - 0s 11ms/step - loss: 439.7295 - val_loss: 456.1525
# Epoch 98/500
# 7/7 [==============================] - 0s 10ms/step - loss: 438.5800 - val_loss: 454.9862
# Epoch 99/500
# 7/7 [==============================] - 0s 8ms/step - loss: 437.4080 - val_loss: 453.8415
# Epoch 100/500
# 7/7 [==============================] - 0s 7ms/step - loss: 436.2753 - val_loss: 452.6780
# Epoch 101/500
# 7/7 [==============================] - 0s 7ms/step - loss: 435.1939 - val_loss: 451.5011
# Epoch 102/500
# 7/7 [==============================] - 0s 9ms/step - loss: 433.9901 - val_loss: 450.3683
# Epoch 103/500
# 7/7 [==============================] - 0s 7ms/step - loss: 432.8472 - val_loss: 449.2354
# Epoch 104/500
# 7/7 [==============================] - 0s 7ms/step - loss: 431.7382 - val_loss: 448.0945
# Epoch 105/500
# 7/7 [==============================] - 0s 10ms/step - loss: 430.6199 - val_loss: 446.9487
# Epoch 106/500
# 7/7 [==============================] - 0s 8ms/step - loss: 429.4766 - val_loss: 445.8345
# Epoch 107/500
# 7/7 [==============================] - 0s 8ms/step - loss: 428.3919 - val_loss: 444.6939
# Epoch 108/500
# 7/7 [==============================] - 0s 8ms/step - loss: 427.2265 - val_loss: 443.5883
# Epoch 109/500
# 7/7 [==============================] - 0s 7ms/step - loss: 426.1176 - val_loss: 442.4792
# Epoch 110/500
# 7/7 [==============================] - 0s 8ms/step - loss: 425.0187 - val_loss: 441.3802
# Epoch 111/500
# 7/7 [==============================] - 0s 7ms/step - loss: 423.9471 - val_loss: 440.2386
# Epoch 112/500
# 7/7 [==============================] - 0s 7ms/step - loss: 422.8044 - val_loss: 439.1557
# Epoch 113/500
# 7/7 [==============================] - 0s 7ms/step - loss: 421.6971 - val_loss: 438.0546
# Epoch 114/500
# 7/7 [==============================] - 0s 7ms/step - loss: 420.6325 - val_loss: 436.9286
# Epoch 115/500
# 7/7 [==============================] - 0s 7ms/step - loss: 419.4989 - val_loss: 435.8419
# Epoch 116/500
# 7/7 [==============================] - 0s 7ms/step - loss: 418.4264 - val_loss: 434.7340
# Epoch 117/500
# 7/7 [==============================] - 0s 7ms/step - loss: 417.3180 - val_loss: 433.6492
# Epoch 118/500
# 7/7 [==============================] - 0s 8ms/step - loss: 416.2504 - val_loss: 432.5461
# Epoch 119/500
# 7/7 [==============================] - 0s 7ms/step - loss: 415.1994 - val_loss: 431.4394
# Epoch 120/500
# 7/7 [==============================] - 0s 7ms/step - loss: 414.0880 - val_loss: 430.3463
# Epoch 121/500
# 7/7 [==============================] - 0s 7ms/step - loss: 412.9856 - val_loss: 429.2723
# Epoch 122/500
# 7/7 [==============================] - 0s 7ms/step - loss: 411.9092 - val_loss: 428.2016
# Epoch 123/500
# 7/7 [==============================] - 0s 16ms/step - loss: 410.8383 - val_loss: 427.1423
# Epoch 124/500
# 7/7 [==============================] - 0s 7ms/step - loss: 409.7786 - val_loss: 426.0677
# Epoch 125/500
# 7/7 [==============================] - 0s 7ms/step - loss: 408.7275 - val_loss: 424.9930
# Epoch 126/500
# 7/7 [==============================] - 0s 7ms/step - loss: 407.6340 - val_loss: 423.9302
# Epoch 127/500
# 7/7 [==============================] - 0s 7ms/step - loss: 406.5744 - val_loss: 422.8599
# Epoch 128/500
# 7/7 [==============================] - 0s 7ms/step - loss: 405.5175 - val_loss: 421.7979
# Epoch 129/500
# 7/7 [==============================] - 0s 9ms/step - loss: 404.4444 - val_loss: 420.7483
# Epoch 130/500
# 7/7 [==============================] - 0s 7ms/step - loss: 403.3991 - val_loss: 419.6858
# Epoch 131/500
# 7/7 [==============================] - 0s 8ms/step - loss: 402.3662 - val_loss: 418.6204
# Epoch 132/500
# 7/7 [==============================] - 0s 8ms/step - loss: 401.2813 - val_loss: 417.5700
# Epoch 133/500
# 7/7 [==============================] - 0s 7ms/step - loss: 400.2523 - val_loss: 416.5154
# Epoch 134/500
# 7/7 [==============================] - 0s 7ms/step - loss: 399.2003 - val_loss: 415.4696
# Epoch 135/500
# 7/7 [==============================] - 0s 7ms/step - loss: 398.1707 - val_loss: 414.4185
# Epoch 136/500
# 7/7 [==============================] - 0s 7ms/step - loss: 397.1060 - val_loss: 413.3800
# Epoch 137/500
# 7/7 [==============================] - 0s 9ms/step - loss: 396.0835 - val_loss: 412.3278
# Epoch 138/500
# 7/7 [==============================] - 0s 8ms/step - loss: 395.0317 - val_loss: 411.2946
# Epoch 139/500
# 7/7 [==============================] - 0s 8ms/step - loss: 393.9977 - val_loss: 410.2674
# Epoch 140/500
# 7/7 [==============================] - 0s 7ms/step - loss: 392.9799 - val_loss: 409.2211
# Epoch 141/500
# 7/7 [==============================] - 0s 7ms/step - loss: 391.9527 - val_loss: 408.1878
# Epoch 142/500
# 7/7 [==============================] - 0s 7ms/step - loss: 390.9308 - val_loss: 407.1456
# Epoch 143/500
# 7/7 [==============================] - 0s 7ms/step - loss: 389.8792 - val_loss: 406.1296
# Epoch 144/500
# 7/7 [==============================] - 0s 7ms/step - loss: 388.8614 - val_loss: 405.1124
# Epoch 145/500
# 7/7 [==============================] - 0s 7ms/step - loss: 387.8303 - val_loss: 404.0922
# Epoch 146/500
# 7/7 [==============================] - 0s 14ms/step - loss: 386.8353 - val_loss: 403.0622
# Epoch 147/500
# 7/7 [==============================] - 0s 7ms/step - loss: 385.8025 - val_loss: 402.0386
# Epoch 148/500
# 7/7 [==============================] - 0s 7ms/step - loss: 384.7911 - val_loss: 401.0284
# Epoch 149/500
# 7/7 [==============================] - 0s 8ms/step - loss: 383.7834 - val_loss: 400.0210
# Epoch 150/500
# 7/7 [==============================] - 0s 7ms/step - loss: 382.7656 - val_loss: 399.0101
# Epoch 151/500
# 7/7 [==============================] - 0s 7ms/step - loss: 381.7833 - val_loss: 397.9870
# Epoch 152/500
# 7/7 [==============================] - 0s 7ms/step - loss: 380.7462 - val_loss: 396.9817
# Epoch 153/500
# 7/7 [==============================] - 0s 10ms/step - loss: 379.7398 - val_loss: 395.9790
# Epoch 154/500
# 7/7 [==============================] - 0s 7ms/step - loss: 378.7452 - val_loss: 394.9826
# Epoch 155/500
# 7/7 [==============================] - 0s 7ms/step - loss: 377.7484 - val_loss: 393.9699
# Epoch 156/500
# 7/7 [==============================] - 0s 7ms/step - loss: 376.7418 - val_loss: 392.9691
# Epoch 157/500
# 7/7 [==============================] - 0s 7ms/step - loss: 375.7440 - val_loss: 391.9707
# Epoch 158/500
# 7/7 [==============================] - 0s 7ms/step - loss: 374.7431 - val_loss: 390.9846
# Epoch 159/500
# 7/7 [==============================] - 0s 7ms/step - loss: 373.7571 - val_loss: 389.9834
# Epoch 160/500
# 7/7 [==============================] - 0s 8ms/step - loss: 372.7700 - val_loss: 389.0061
# Epoch 161/500
# 7/7 [==============================] - 0s 7ms/step - loss: 371.8168 - val_loss: 387.9950
# Epoch 162/500
# 7/7 [==============================] - 0s 7ms/step - loss: 370.8009 - val_loss: 387.0004
# Epoch 163/500
# 7/7 [==============================] - 0s 7ms/step - loss: 369.8042 - val_loss: 386.0147
# Epoch 164/500
# 7/7 [==============================] - 0s 7ms/step - loss: 368.8207 - val_loss: 385.0399
# Epoch 165/500
# 7/7 [==============================] - 0s 6ms/step - loss: 367.8510 - val_loss: 384.0608
# Epoch 166/500
# 7/7 [==============================] - 0s 7ms/step - loss: 366.8605 - val_loss: 383.0887
# Epoch 167/500
# 7/7 [==============================] - 0s 7ms/step - loss: 365.9057 - val_loss: 382.0967
# Epoch 168/500
# 7/7 [==============================] - 0s 6ms/step - loss: 364.9211 - val_loss: 381.1319
# Epoch 169/500
# 7/7 [==============================] - 0s 16ms/step - loss: 363.9713 - val_loss: 380.1502
# Epoch 170/500
# 7/7 [==============================] - 0s 7ms/step - loss: 362.9773 - val_loss: 379.1788
# Epoch 171/500
# 7/7 [==============================] - 0s 7ms/step - loss: 362.0010 - val_loss: 378.2134
# Epoch 172/500
# 7/7 [==============================] - 0s 7ms/step - loss: 361.0511 - val_loss: 377.2470
# Epoch 173/500
# 7/7 [==============================] - 0s 9ms/step - loss: 360.0759 - val_loss: 376.2755
# Epoch 174/500
# 7/7 [==============================] - 0s 7ms/step - loss: 359.1282 - val_loss: 375.3010
# Epoch 175/500
# 7/7 [==============================] - 0s 7ms/step - loss: 358.1451 - val_loss: 374.3395
# Epoch 176/500
# 7/7 [==============================] - 0s 7ms/step - loss: 357.1919 - val_loss: 373.3824
# Epoch 177/500
# 7/7 [==============================] - 0s 6ms/step - loss: 356.2328 - val_loss: 372.4231
# Epoch 178/500
# 7/7 [==============================] - 0s 9ms/step - loss: 355.3089 - val_loss: 371.4632
# Epoch 179/500
# 7/7 [==============================] - 0s 8ms/step - loss: 354.3307 - val_loss: 370.5051
# Epoch 180/500
# 7/7 [==============================] - 0s 8ms/step - loss: 353.3672 - val_loss: 369.5559
# Epoch 181/500
# 7/7 [==============================] - 0s 8ms/step - loss: 352.4250 - val_loss: 368.6038
# Epoch 182/500
# 7/7 [==============================] - 0s 8ms/step - loss: 351.4771 - val_loss: 367.6560
# Epoch 183/500
# 7/7 [==============================] - 0s 7ms/step - loss: 350.5287 - val_loss: 366.7131
# Epoch 184/500
# 7/7 [==============================] - 0s 7ms/step - loss: 349.5920 - val_loss: 365.7703
# Epoch 185/500
# 7/7 [==============================] - 0s 7ms/step - loss: 348.6551 - val_loss: 364.8167
# Epoch 186/500
# 7/7 [==============================] - 0s 7ms/step - loss: 347.7166 - val_loss: 363.8800
# Epoch 187/500
# 7/7 [==============================] - 0s 7ms/step - loss: 346.7705 - val_loss: 362.9366
# Epoch 188/500
# 7/7 [==============================] - 0s 7ms/step - loss: 345.8280 - val_loss: 361.9928
# Epoch 189/500
# 7/7 [==============================] - 0s 7ms/step - loss: 344.9151 - val_loss: 361.0560
# Epoch 190/500
# 7/7 [==============================] - 0s 7ms/step - loss: 343.9640 - val_loss: 360.1222
# Epoch 191/500
# 7/7 [==============================] - 0s 21ms/step - loss: 343.0329 - val_loss: 359.1916
# Epoch 192/500
# 7/7 [==============================] - 0s 7ms/step - loss: 342.1050 - val_loss: 358.2570
# Epoch 193/500
# 7/7 [==============================] - 0s 7ms/step - loss: 341.1718 - val_loss: 357.3328
# Epoch 194/500
# 7/7 [==============================] - 0s 7ms/step - loss: 340.2838 - val_loss: 356.3907
# Epoch 195/500
# 7/7 [==============================] - 0s 7ms/step - loss: 339.3414 - val_loss: 355.4743
# Epoch 196/500
# 7/7 [==============================] - 0s 7ms/step - loss: 338.4249 - val_loss: 354.5457
# Epoch 197/500
# 7/7 [==============================] - 0s 7ms/step - loss: 337.4916 - val_loss: 353.6290
# Epoch 198/500
# 7/7 [==============================] - 0s 7ms/step - loss: 336.5731 - val_loss: 352.7050
# Epoch 199/500
# 7/7 [==============================] - 0s 7ms/step - loss: 335.6577 - val_loss: 351.7841
# Epoch 200/500
# 7/7 [==============================] - 0s 7ms/step - loss: 334.7573 - val_loss: 350.8704
# Epoch 201/500
# 7/7 [==============================] - 0s 7ms/step - loss: 333.8336 - val_loss: 349.9576
# Epoch 202/500
# 7/7 [==============================] - 0s 6ms/step - loss: 332.9310 - val_loss: 349.0377
# Epoch 203/500
# 7/7 [==============================] - 0s 7ms/step - loss: 332.0271 - val_loss: 348.1299
# Epoch 204/500
# 7/7 [==============================] - 0s 7ms/step - loss: 331.1172 - val_loss: 347.2081
# Epoch 205/500
# 7/7 [==============================] - 0s 7ms/step - loss: 330.2465 - val_loss: 346.3156
# Epoch 206/500
# 7/7 [==============================] - 0s 7ms/step - loss: 329.3022 - val_loss: 345.4020
# Epoch 207/500
# 7/7 [==============================] - 0s 7ms/step - loss: 328.4052 - val_loss: 344.4922
# Epoch 208/500
# 7/7 [==============================] - 0s 7ms/step - loss: 327.4965 - val_loss: 343.5896
# Epoch 209/500
# 7/7 [==============================] - 0s 10ms/step - loss: 326.6277 - val_loss: 342.6878
# Epoch 210/500
# 7/7 [==============================] - 0s 8ms/step - loss: 325.7115 - val_loss: 341.7957
# Epoch 211/500
# 7/7 [==============================] - 0s 7ms/step - loss: 324.8148 - val_loss: 340.8928
# Epoch 212/500
# 7/7 [==============================] - 0s 12ms/step - loss: 323.9155 - val_loss: 340.0004
# Epoch 213/500
# 7/7 [==============================] - 0s 7ms/step - loss: 323.0334 - val_loss: 339.1036
# Epoch 214/500
# 7/7 [==============================] - 0s 7ms/step - loss: 322.1362 - val_loss: 338.2048
# Epoch 215/500
# 7/7 [==============================] - 0s 7ms/step - loss: 321.2606 - val_loss: 337.3136
# Epoch 216/500
# 7/7 [==============================] - 0s 7ms/step - loss: 320.3663 - val_loss: 336.4272
# Epoch 217/500
# 7/7 [==============================] - 0s 7ms/step - loss: 319.4954 - val_loss: 335.5452
# Epoch 218/500
# 7/7 [==============================] - 0s 8ms/step - loss: 318.5979 - val_loss: 334.6585
# Epoch 219/500
# 7/7 [==============================] - 0s 7ms/step - loss: 317.7257 - val_loss: 333.7695
# Epoch 220/500
# 7/7 [==============================] - 0s 8ms/step - loss: 316.8465 - val_loss: 332.8876
# Epoch 221/500
# 7/7 [==============================] - 0s 7ms/step - loss: 315.9699 - val_loss: 332.0049
# Epoch 222/500
# 7/7 [==============================] - 0s 7ms/step - loss: 315.1171 - val_loss: 331.1168
# Epoch 223/500
# 7/7 [==============================] - 0s 7ms/step - loss: 314.2328 - val_loss: 330.2462
# Epoch 224/500
# 7/7 [==============================] - 0s 7ms/step - loss: 313.3558 - val_loss: 329.3706
# Epoch 225/500
# 7/7 [==============================] - 0s 9ms/step - loss: 312.4896 - val_loss: 328.4916
# Epoch 226/500
# 7/7 [==============================] - 0s 7ms/step - loss: 311.6067 - val_loss: 327.6177
# Epoch 227/500
# 7/7 [==============================] - 0s 7ms/step - loss: 310.7422 - val_loss: 326.7505
# Epoch 228/500
# 7/7 [==============================] - 0s 7ms/step - loss: 309.8943 - val_loss: 325.8830
# Epoch 229/500
# 7/7 [==============================] - 0s 7ms/step - loss: 309.0243 - val_loss: 325.0148
# Epoch 230/500
# 7/7 [==============================] - 0s 7ms/step - loss: 308.1584 - val_loss: 324.1430
# Epoch 231/500
# 7/7 [==============================] - 0s 7ms/step - loss: 307.3140 - val_loss: 323.2652
# Epoch 232/500
# 7/7 [==============================] - 0s 9ms/step - loss: 306.4356 - val_loss: 322.4058
# Epoch 233/500
# 7/7 [==============================] - 0s 8ms/step - loss: 305.5927 - val_loss: 321.5525
# Epoch 234/500
# 7/7 [==============================] - 0s 6ms/step - loss: 304.7391 - val_loss: 320.6883
# Epoch 235/500
# 7/7 [==============================] - 0s 7ms/step - loss: 303.8760 - val_loss: 319.8296
# Epoch 236/500
# 7/7 [==============================] - 0s 7ms/step - loss: 303.0277 - val_loss: 318.9676
# Epoch 237/500
# 7/7 [==============================] - 0s 7ms/step - loss: 302.1790 - val_loss: 318.1122
# Epoch 238/500
# 7/7 [==============================] - 0s 8ms/step - loss: 301.3372 - val_loss: 317.2694
# Epoch 239/500
# 7/7 [==============================] - 0s 11ms/step - loss: 300.4927 - val_loss: 316.4104
# Epoch 240/500
# 7/7 [==============================] - 0s 8ms/step - loss: 299.6423 - val_loss: 315.5585
# Epoch 241/500
# 7/7 [==============================] - 0s 7ms/step - loss: 298.8077 - val_loss: 314.7146
# Epoch 242/500
# 7/7 [==============================] - 0s 7ms/step - loss: 297.9654 - val_loss: 313.8676
# Epoch 243/500
# 7/7 [==============================] - 0s 7ms/step - loss: 297.1323 - val_loss: 313.0276
# Epoch 244/500
# 7/7 [==============================] - 0s 7ms/step - loss: 296.2847 - val_loss: 312.1802
# Epoch 245/500
# 7/7 [==============================] - 0s 7ms/step - loss: 295.4451 - val_loss: 311.3381
# Epoch 246/500
# 7/7 [==============================] - 0s 7ms/step - loss: 294.6248 - val_loss: 310.5058
# Epoch 247/500
# 7/7 [==============================] - 0s 7ms/step - loss: 293.8311 - val_loss: 309.6499
# Epoch 248/500
# 7/7 [==============================] - 0s 8ms/step - loss: 292.9470 - val_loss: 308.8138
# Epoch 249/500
# 7/7 [==============================] - 0s 8ms/step - loss: 292.1209 - val_loss: 307.9846
# Epoch 250/500
# 7/7 [==============================] - 0s 9ms/step - loss: 291.3112 - val_loss: 307.1561
# Epoch 251/500
# 7/7 [==============================] - 0s 7ms/step - loss: 290.4641 - val_loss: 306.3185
# Epoch 252/500
# 7/7 [==============================] - 0s 7ms/step - loss: 289.6447 - val_loss: 305.4872
# Epoch 253/500
# 7/7 [==============================] - 0s 7ms/step - loss: 288.8291 - val_loss: 304.6511
# Epoch 254/500
# 7/7 [==============================] - 0s 16ms/step - loss: 288.0086 - val_loss: 303.8284
# Epoch 255/500
# 7/7 [==============================] - 0s 7ms/step - loss: 287.1832 - val_loss: 303.0109
# Epoch 256/500
# 7/7 [==============================] - 0s 7ms/step - loss: 286.3673 - val_loss: 302.1827
# Epoch 257/500
# 7/7 [==============================] - 0s 7ms/step - loss: 285.5642 - val_loss: 301.3562
# Epoch 258/500
# 7/7 [==============================] - 0s 8ms/step - loss: 284.7363 - val_loss: 300.5410
# Epoch 259/500
# 7/7 [==============================] - 0s 8ms/step - loss: 283.9374 - val_loss: 299.7117
# Epoch 260/500
# 7/7 [==============================] - 0s 8ms/step - loss: 283.1439 - val_loss: 298.8816
# Epoch 261/500
# 7/7 [==============================] - 0s 7ms/step - loss: 282.3008 - val_loss: 298.0662
# Epoch 262/500
# 7/7 [==============================] - 0s 7ms/step - loss: 281.5034 - val_loss: 297.2537
# Epoch 263/500
# 7/7 [==============================] - 0s 10ms/step - loss: 280.6964 - val_loss: 296.4402
# Epoch 264/500
# 7/7 [==============================] - 0s 7ms/step - loss: 279.8925 - val_loss: 295.6378
# Epoch 265/500
# 7/7 [==============================] - 0s 7ms/step - loss: 279.0896 - val_loss: 294.8243
# Epoch 266/500
# 7/7 [==============================] - 0s 7ms/step - loss: 278.2885 - val_loss: 294.0187
# Epoch 267/500
# 7/7 [==============================] - 0s 7ms/step - loss: 277.4884 - val_loss: 293.2083
# Epoch 268/500
# 7/7 [==============================] - 0s 7ms/step - loss: 276.6956 - val_loss: 292.3971
# Epoch 269/500
# 7/7 [==============================] - 0s 7ms/step - loss: 275.8985 - val_loss: 291.5990
# Epoch 270/500
# 7/7 [==============================] - 0s 7ms/step - loss: 275.0935 - val_loss: 290.7985
# Epoch 271/500
# 7/7 [==============================] - 0s 8ms/step - loss: 274.3080 - val_loss: 290.0069
# Epoch 272/500
# 7/7 [==============================] - 0s 7ms/step - loss: 273.5145 - val_loss: 289.2019
# Epoch 273/500
# 7/7 [==============================] - 0s 7ms/step - loss: 272.7385 - val_loss: 288.4108
# Epoch 274/500
# 7/7 [==============================] - 0s 14ms/step - loss: 271.9271 - val_loss: 287.6113
# Epoch 275/500
# 7/7 [==============================] - 0s 7ms/step - loss: 271.1566 - val_loss: 286.8051
# Epoch 276/500
# 7/7 [==============================] - 0s 9ms/step - loss: 270.3614 - val_loss: 286.0195
# Epoch 277/500
# 7/7 [==============================] - 0s 7ms/step - loss: 269.5891 - val_loss: 285.2264
# Epoch 278/500
# 7/7 [==============================] - 0s 7ms/step - loss: 268.8048 - val_loss: 284.4383
# Epoch 279/500
# 7/7 [==============================] - 0s 7ms/step - loss: 268.0229 - val_loss: 283.6459
# Epoch 280/500
# 7/7 [==============================] - 0s 7ms/step - loss: 267.2458 - val_loss: 282.8635
# Epoch 281/500
# 7/7 [==============================] - 0s 7ms/step - loss: 266.5092 - val_loss: 282.0549
# Epoch 282/500
# 7/7 [==============================] - 0s 7ms/step - loss: 265.6890 - val_loss: 281.2788
# Epoch 283/500
# 7/7 [==============================] - 0s 7ms/step - loss: 264.9353 - val_loss: 280.5027
# Epoch 284/500
# 7/7 [==============================] - 0s 7ms/step - loss: 264.1481 - val_loss: 279.7134
# Epoch 285/500
# 7/7 [==============================] - 0s 8ms/step - loss: 263.3694 - val_loss: 278.9374
# Epoch 286/500
# 7/7 [==============================] - 0s 7ms/step - loss: 262.6039 - val_loss: 278.1513
# Epoch 287/500
# 7/7 [==============================] - 0s 8ms/step - loss: 261.8386 - val_loss: 277.3691
# Epoch 288/500
# 7/7 [==============================] - 0s 7ms/step - loss: 261.0715 - val_loss: 276.6015
# Epoch 289/500
# 7/7 [==============================] - 0s 10ms/step - loss: 260.3255 - val_loss: 275.8404
# Epoch 290/500
# 7/7 [==============================] - 0s 7ms/step - loss: 259.5448 - val_loss: 275.0701
# Epoch 291/500
# 7/7 [==============================] - 0s 7ms/step - loss: 258.7850 - val_loss: 274.2925
# Epoch 292/500
# 7/7 [==============================] - 0s 7ms/step - loss: 258.0190 - val_loss: 273.5266
# Epoch 293/500
# 7/7 [==============================] - 0s 7ms/step - loss: 257.2705 - val_loss: 272.7486
# Epoch 294/500
# 7/7 [==============================] - 0s 7ms/step - loss: 256.5164 - val_loss: 271.9907
# Epoch 295/500
# 7/7 [==============================] - 0s 9ms/step - loss: 255.7544 - val_loss: 271.2186
# Epoch 296/500
# 7/7 [==============================] - 0s 7ms/step - loss: 254.9991 - val_loss: 270.4558
# Epoch 297/500
# 7/7 [==============================] - 0s 7ms/step - loss: 254.2567 - val_loss: 269.6897
# Epoch 298/500
# 7/7 [==============================] - 0s 8ms/step - loss: 253.5077 - val_loss: 268.9397
# Epoch 299/500
# 7/7 [==============================] - 0s 8ms/step - loss: 252.7574 - val_loss: 268.1728
# Epoch 300/500
# 7/7 [==============================] - 0s 11ms/step - loss: 252.0060 - val_loss: 267.4153
# Epoch 301/500
# 7/7 [==============================] - 0s 9ms/step - loss: 251.2655 - val_loss: 266.6597
# Epoch 302/500
# 7/7 [==============================] - 0s 7ms/step - loss: 250.5118 - val_loss: 265.9047
# Epoch 303/500
# 7/7 [==============================] - 0s 7ms/step - loss: 249.7882 - val_loss: 265.1535
# Epoch 304/500
# 7/7 [==============================] - 0s 7ms/step - loss: 249.0306 - val_loss: 264.3991
# Epoch 305/500
# 7/7 [==============================] - 0s 7ms/step - loss: 248.2933 - val_loss: 263.6502
# Epoch 306/500
# 7/7 [==============================] - 0s 7ms/step - loss: 247.5559 - val_loss: 262.9022
# Epoch 307/500
# 7/7 [==============================] - 0s 7ms/step - loss: 246.8163 - val_loss: 262.1537
# Epoch 308/500
# 7/7 [==============================] - 0s 7ms/step - loss: 246.0859 - val_loss: 261.4121
# Epoch 309/500
# 7/7 [==============================] - 0s 7ms/step - loss: 245.3568 - val_loss: 260.6765
# Epoch 310/500
# 7/7 [==============================] - 0s 7ms/step - loss: 244.6394 - val_loss: 259.9183
# Epoch 311/500
# 7/7 [==============================] - 0s 7ms/step - loss: 243.8896 - val_loss: 259.1811
# Epoch 312/500
# 7/7 [==============================] - 0s 10ms/step - loss: 243.1570 - val_loss: 258.4424
# Epoch 313/500
# 7/7 [==============================] - 0s 15ms/step - loss: 242.4386 - val_loss: 257.6945
# Epoch 314/500
# 7/7 [==============================] - 0s 8ms/step - loss: 241.7212 - val_loss: 256.9745
# Epoch 315/500
# 7/7 [==============================] - 0s 7ms/step - loss: 240.9887 - val_loss: 256.2307
# Epoch 316/500
# 7/7 [==============================] - 0s 7ms/step - loss: 240.2799 - val_loss: 255.4865
# Epoch 317/500
# 7/7 [==============================] - 0s 7ms/step - loss: 239.5371 - val_loss: 254.7590
# Epoch 318/500
# 7/7 [==============================] - 0s 7ms/step - loss: 238.8196 - val_loss: 254.0332
# Epoch 319/500
# 7/7 [==============================] - 0s 7ms/step - loss: 238.1110 - val_loss: 253.3124
# Epoch 320/500
# 7/7 [==============================] - 0s 7ms/step - loss: 237.3836 - val_loss: 252.5778
# Epoch 321/500
# 7/7 [==============================] - 0s 7ms/step - loss: 236.6744 - val_loss: 251.8508
# Epoch 322/500
# 7/7 [==============================] - 0s 10ms/step - loss: 235.9576 - val_loss: 251.1300
# Epoch 323/500
# 7/7 [==============================] - 0s 7ms/step - loss: 235.2494 - val_loss: 250.3990
# Epoch 324/500
# 7/7 [==============================] - 0s 7ms/step - loss: 234.5495 - val_loss: 249.6669
# Epoch 325/500
# 7/7 [==============================] - 0s 8ms/step - loss: 233.8315 - val_loss: 248.9450
# Epoch 326/500
# 7/7 [==============================] - 0s 7ms/step - loss: 233.1217 - val_loss: 248.2257
# Epoch 327/500
# 7/7 [==============================] - 0s 7ms/step - loss: 232.4099 - val_loss: 247.5138
# Epoch 328/500
# 7/7 [==============================] - 0s 7ms/step - loss: 231.7155 - val_loss: 246.8034
# Epoch 329/500
# 7/7 [==============================] - 0s 7ms/step - loss: 231.0050 - val_loss: 246.0798
# Epoch 330/500
# 7/7 [==============================] - 0s 7ms/step - loss: 230.3049 - val_loss: 245.3625
# Epoch 331/500
# 7/7 [==============================] - 0s 7ms/step - loss: 229.6169 - val_loss: 244.6406
# Epoch 332/500
# 7/7 [==============================] - 0s 8ms/step - loss: 228.9053 - val_loss: 243.9420
# Epoch 333/500
# 7/7 [==============================] - 0s 18ms/step - loss: 228.2162 - val_loss: 243.2452
# Epoch 334/500
# 7/7 [==============================] - 0s 7ms/step - loss: 227.5179 - val_loss: 242.5360
# Epoch 335/500
# 7/7 [==============================] - 0s 7ms/step - loss: 226.8105 - val_loss: 241.8274
# Epoch 336/500
# 7/7 [==============================] - 0s 7ms/step - loss: 226.1235 - val_loss: 241.1144
# Epoch 337/500
# 7/7 [==============================] - 0s 7ms/step - loss: 225.4295 - val_loss: 240.4115
# Epoch 338/500
# 7/7 [==============================] - 0s 7ms/step - loss: 224.7373 - val_loss: 239.7060
# Epoch 339/500
# 7/7 [==============================] - 0s 8ms/step - loss: 224.0538 - val_loss: 239.0059
# Epoch 340/500
# 7/7 [==============================] - 0s 8ms/step - loss: 223.3661 - val_loss: 238.3130
# Epoch 341/500
# 7/7 [==============================] - 0s 7ms/step - loss: 222.6873 - val_loss: 237.6071
# Epoch 342/500
# 7/7 [==============================] - 0s 8ms/step - loss: 221.9961 - val_loss: 236.9105
# Epoch 343/500
# 7/7 [==============================] - 0s 11ms/step - loss: 221.3146 - val_loss: 236.2084
# Epoch 344/500
# 7/7 [==============================] - 0s 8ms/step - loss: 220.6369 - val_loss: 235.5213
# Epoch 345/500
# 7/7 [==============================] - 0s 7ms/step - loss: 219.9588 - val_loss: 234.8252
# Epoch 346/500
# 7/7 [==============================] - 0s 7ms/step - loss: 219.2660 - val_loss: 234.1443
# Epoch 347/500
# 7/7 [==============================] - 0s 7ms/step - loss: 218.6004 - val_loss: 233.4474
# Epoch 348/500
# 7/7 [==============================] - 0s 8ms/step - loss: 217.9291 - val_loss: 232.7479
# Epoch 349/500
# 7/7 [==============================] - 0s 7ms/step - loss: 217.2506 - val_loss: 232.0657
# Epoch 350/500
# 7/7 [==============================] - 0s 16ms/step - loss: 216.5765 - val_loss: 231.3847
# Epoch 351/500
# 7/7 [==============================] - 0s 7ms/step - loss: 215.9020 - val_loss: 230.6959
# Epoch 352/500
# 7/7 [==============================] - 0s 8ms/step - loss: 215.2456 - val_loss: 230.0212
# Epoch 353/500
# 7/7 [==============================] - 0s 10ms/step - loss: 214.5687 - val_loss: 229.3407
# Epoch 354/500
# 7/7 [==============================] - 0s 8ms/step - loss: 213.9214 - val_loss: 228.6534
# Epoch 355/500
# 7/7 [==============================] - 0s 7ms/step - loss: 213.2398 - val_loss: 227.9796
# Epoch 356/500
# 7/7 [==============================] - 0s 8ms/step - loss: 212.5656 - val_loss: 227.2972
# Epoch 357/500
# 7/7 [==============================] - 0s 7ms/step - loss: 211.9192 - val_loss: 226.6089
# Epoch 358/500
# 7/7 [==============================] - 0s 7ms/step - loss: 211.2467 - val_loss: 225.9369
# Epoch 359/500
# 7/7 [==============================] - 0s 7ms/step - loss: 210.5894 - val_loss: 225.2624
# Epoch 360/500
# 7/7 [==============================] - 0s 7ms/step - loss: 209.9470 - val_loss: 224.5900
# Epoch 361/500
# 7/7 [==============================] - 0s 7ms/step - loss: 209.2759 - val_loss: 223.9207
# Epoch 362/500
# 7/7 [==============================] - 0s 7ms/step - loss: 208.6201 - val_loss: 223.2621
# Epoch 363/500
# 7/7 [==============================] - 0s 10ms/step - loss: 207.9651 - val_loss: 222.5978
# Epoch 364/500
# 7/7 [==============================] - 0s 8ms/step - loss: 207.3248 - val_loss: 221.9407
# Epoch 365/500
# 7/7 [==============================] - 0s 7ms/step - loss: 206.6635 - val_loss: 221.2651
# Epoch 366/500
# 7/7 [==============================] - 0s 7ms/step - loss: 206.0152 - val_loss: 220.5979
# Epoch 367/500
# 7/7 [==============================] - 0s 7ms/step - loss: 205.3647 - val_loss: 219.9382
# Epoch 368/500
# 7/7 [==============================] - 0s 16ms/step - loss: 204.7160 - val_loss: 219.2683
# Epoch 369/500
# 7/7 [==============================] - 0s 7ms/step - loss: 204.0672 - val_loss: 218.6083
# Epoch 370/500
# 7/7 [==============================] - 0s 7ms/step - loss: 203.4276 - val_loss: 217.9565
# Epoch 371/500
# 7/7 [==============================] - 0s 7ms/step - loss: 202.7913 - val_loss: 217.3002
# Epoch 372/500
# 7/7 [==============================] - 0s 10ms/step - loss: 202.1413 - val_loss: 216.6531
# Epoch 373/500
# 7/7 [==============================] - 0s 7ms/step - loss: 201.5191 - val_loss: 215.9814
# Epoch 374/500
# 7/7 [==============================] - 0s 7ms/step - loss: 200.8606 - val_loss: 215.3340
# Epoch 375/500
# 7/7 [==============================] - 0s 7ms/step - loss: 200.2447 - val_loss: 214.6638
# Epoch 376/500
# 7/7 [==============================] - 0s 7ms/step - loss: 199.5962 - val_loss: 214.0218
# Epoch 377/500
# 7/7 [==============================] - 0s 7ms/step - loss: 198.9556 - val_loss: 213.3728
# Epoch 378/500
# 7/7 [==============================] - 0s 8ms/step - loss: 198.3209 - val_loss: 212.7254
# Epoch 379/500
# 7/7 [==============================] - 0s 8ms/step - loss: 197.6871 - val_loss: 212.0770
# Epoch 380/500
# 7/7 [==============================] - 0s 7ms/step - loss: 197.0709 - val_loss: 211.4347
# Epoch 381/500
# 7/7 [==============================] - 0s 7ms/step - loss: 196.4320 - val_loss: 210.7999
# Epoch 382/500
# 7/7 [==============================] - 0s 10ms/step - loss: 195.8104 - val_loss: 210.1475
# Epoch 383/500
# 7/7 [==============================] - 0s 7ms/step - loss: 195.1858 - val_loss: 209.5052
# Epoch 384/500
# 7/7 [==============================] - 0s 14ms/step - loss: 194.5509 - val_loss: 208.8675
# Epoch 385/500
# 7/7 [==============================] - 0s 8ms/step - loss: 193.9428 - val_loss: 208.2182
# Epoch 386/500
# 7/7 [==============================] - 0s 8ms/step - loss: 193.3241 - val_loss: 207.5764
# Epoch 387/500
# 7/7 [==============================] - 0s 7ms/step - loss: 192.6915 - val_loss: 206.9440
# Epoch 388/500
# 7/7 [==============================] - 0s 7ms/step - loss: 192.0691 - val_loss: 206.3131
# Epoch 389/500
# 7/7 [==============================] - 0s 7ms/step - loss: 191.4558 - val_loss: 205.6858
# Epoch 390/500
# 7/7 [==============================] - 0s 7ms/step - loss: 190.8385 - val_loss: 205.0509
# Epoch 391/500
# 7/7 [==============================] - 0s 7ms/step - loss: 190.2333 - val_loss: 204.4143
# Epoch 392/500
# 7/7 [==============================] - 0s 7ms/step - loss: 189.6101 - val_loss: 203.7867
# Epoch 393/500
# 7/7 [==============================] - 0s 8ms/step - loss: 189.0089 - val_loss: 203.1693
# Epoch 394/500
# 7/7 [==============================] - 0s 7ms/step - loss: 188.3860 - val_loss: 202.5389
# Epoch 395/500
# 7/7 [==============================] - 0s 7ms/step - loss: 187.7771 - val_loss: 201.9073
# Epoch 396/500
# 7/7 [==============================] - 0s 7ms/step - loss: 187.1714 - val_loss: 201.2818
# Epoch 397/500
# 7/7 [==============================] - 0s 8ms/step - loss: 186.5616 - val_loss: 200.6644
# Epoch 398/500
# 7/7 [==============================] - 0s 8ms/step - loss: 185.9548 - val_loss: 200.0459
# Epoch 399/500
# 7/7 [==============================] - 0s 6ms/step - loss: 185.3506 - val_loss: 199.4272
# Epoch 400/500
# 7/7 [==============================] - 0s 8ms/step - loss: 184.7528 - val_loss: 198.7999
# Epoch 401/500
# 7/7 [==============================] - 0s 17ms/step - loss: 184.1442 - val_loss: 198.1854
# Epoch 402/500
# 7/7 [==============================] - 0s 7ms/step - loss: 183.5534 - val_loss: 197.5644
# Epoch 403/500
# 7/7 [==============================] - 0s 7ms/step - loss: 182.9497 - val_loss: 196.9563
# Epoch 404/500
# 7/7 [==============================] - 0s 7ms/step - loss: 182.3461 - val_loss: 196.3481
# Epoch 405/500
# 7/7 [==============================] - 0s 7ms/step - loss: 181.7625 - val_loss: 195.7371
# Epoch 406/500
# 7/7 [==============================] - 0s 7ms/step - loss: 181.1698 - val_loss: 195.1275
# Epoch 407/500
# 7/7 [==============================] - 0s 7ms/step - loss: 180.5678 - val_loss: 194.5109
# Epoch 408/500
# 7/7 [==============================] - 0s 7ms/step - loss: 179.9814 - val_loss: 193.9086
# Epoch 409/500
# 7/7 [==============================] - 0s 7ms/step - loss: 179.3867 - val_loss: 193.2994
# Epoch 410/500
# 7/7 [==============================] - 0s 10ms/step - loss: 178.7918 - val_loss: 192.6964
# Epoch 411/500
# 7/7 [==============================] - 0s 7ms/step - loss: 178.2098 - val_loss: 192.0888
# Epoch 412/500
# 7/7 [==============================] - 0s 7ms/step - loss: 177.6259 - val_loss: 191.4911
# Epoch 413/500
# 7/7 [==============================] - 0s 7ms/step - loss: 177.0357 - val_loss: 190.8895
# Epoch 414/500
# 7/7 [==============================] - 0s 7ms/step - loss: 176.4658 - val_loss: 190.2786
# Epoch 415/500
# 7/7 [==============================] - 0s 7ms/step - loss: 175.8711 - val_loss: 189.6786
# Epoch 416/500
# 7/7 [==============================] - 0s 7ms/step - loss: 175.2903 - val_loss: 189.0893
# Epoch 417/500
# 7/7 [==============================] - 0s 7ms/step - loss: 174.7089 - val_loss: 188.4881
# Epoch 418/500
# 7/7 [==============================] - 0s 8ms/step - loss: 174.1331 - val_loss: 187.8865
# Epoch 419/500
# 7/7 [==============================] - 0s 19ms/step - loss: 173.5657 - val_loss: 187.3093
# Epoch 420/500
# 7/7 [==============================] - 0s 7ms/step - loss: 172.9792 - val_loss: 186.7226
# Epoch 421/500
# 7/7 [==============================] - 0s 6ms/step - loss: 172.4092 - val_loss: 186.1190
# Epoch 422/500
# 7/7 [==============================] - 0s 7ms/step - loss: 171.8291 - val_loss: 185.5362
# Epoch 423/500
# 7/7 [==============================] - 0s 7ms/step - loss: 171.2705 - val_loss: 184.9427
# Epoch 424/500
# 7/7 [==============================] - 0s 7ms/step - loss: 170.6981 - val_loss: 184.3561
# Epoch 425/500
# 7/7 [==============================] - 0s 7ms/step - loss: 170.1359 - val_loss: 183.7603
# Epoch 426/500
# 7/7 [==============================] - 0s 7ms/step - loss: 169.5465 - val_loss: 183.1724
# Epoch 427/500
# 7/7 [==============================] - 0s 9ms/step - loss: 168.9951 - val_loss: 182.5979
# Epoch 428/500
# 7/7 [==============================] - 0s 7ms/step - loss: 168.4257 - val_loss: 182.0226
# Epoch 429/500
# 7/7 [==============================] - 0s 7ms/step - loss: 167.8495 - val_loss: 181.4399
# Epoch 430/500
# 7/7 [==============================] - 0s 7ms/step - loss: 167.2975 - val_loss: 180.8609
# Epoch 431/500
# 7/7 [==============================] - 0s 7ms/step - loss: 166.7399 - val_loss: 180.2735
# Epoch 432/500
# 7/7 [==============================] - 0s 7ms/step - loss: 166.1683 - val_loss: 179.6982
# Epoch 433/500
# 7/7 [==============================] - 0s 8ms/step - loss: 165.6100 - val_loss: 179.1208
# Epoch 434/500
# 7/7 [==============================] - 0s 6ms/step - loss: 165.0550 - val_loss: 178.5403
# Epoch 435/500
# 7/7 [==============================] - 0s 7ms/step - loss: 164.4948 - val_loss: 177.9723
# Epoch 436/500
# 7/7 [==============================] - 0s 8ms/step - loss: 163.9452 - val_loss: 177.3960
# Epoch 437/500
# 7/7 [==============================] - 0s 7ms/step - loss: 163.4022 - val_loss: 176.8182
# Epoch 438/500
# 7/7 [==============================] - 0s 7ms/step - loss: 162.8402 - val_loss: 176.2458
# Epoch 439/500
# 7/7 [==============================] - 0s 7ms/step - loss: 162.2868 - val_loss: 175.6792
# Epoch 440/500
# 7/7 [==============================] - 0s 7ms/step - loss: 161.7276 - val_loss: 175.1149
# Epoch 441/500
# 7/7 [==============================] - 0s 7ms/step - loss: 161.1933 - val_loss: 174.5457
# Epoch 442/500
# 7/7 [==============================] - 0s 6ms/step - loss: 160.6394 - val_loss: 173.9899
# Epoch 443/500
# 7/7 [==============================] - 0s 9ms/step - loss: 160.0936 - val_loss: 173.4254
# Epoch 444/500
# 7/7 [==============================] - 0s 8ms/step - loss: 159.5469 - val_loss: 172.8595
# Epoch 445/500
# 7/7 [==============================] - 0s 7ms/step - loss: 159.0062 - val_loss: 172.3002
# Epoch 446/500
# 7/7 [==============================] - 0s 7ms/step - loss: 158.4698 - val_loss: 171.7373
# Epoch 447/500
# 7/7 [==============================] - 0s 7ms/step - loss: 157.9298 - val_loss: 171.1837
# Epoch 448/500
# 7/7 [==============================] - 0s 8ms/step - loss: 157.3992 - val_loss: 170.6153
# Epoch 449/500
# 7/7 [==============================] - 0s 7ms/step - loss: 156.8452 - val_loss: 170.0718
# Epoch 450/500
# 7/7 [==============================] - 0s 7ms/step - loss: 156.3144 - val_loss: 169.5191
# Epoch 451/500
# 7/7 [==============================] - 0s 8ms/step - loss: 155.7778 - val_loss: 168.9728
# Epoch 452/500
# 7/7 [==============================] - 0s 18ms/step - loss: 155.2460 - val_loss: 168.4122
# Epoch 453/500
# 7/7 [==============================] - 0s 8ms/step - loss: 154.7050 - val_loss: 167.8625
# Epoch 454/500
# 7/7 [==============================] - 0s 7ms/step - loss: 154.1719 - val_loss: 167.3107
# Epoch 455/500
# 7/7 [==============================] - 0s 7ms/step - loss: 153.6423 - val_loss: 166.7613
# Epoch 456/500
# 7/7 [==============================] - 0s 7ms/step - loss: 153.1145 - val_loss: 166.2157
# Epoch 457/500
# 7/7 [==============================] - 0s 7ms/step - loss: 152.5903 - val_loss: 165.6645
# Epoch 458/500
# 7/7 [==============================] - 0s 8ms/step - loss: 152.0695 - val_loss: 165.1186
# Epoch 459/500
# 7/7 [==============================] - 0s 8ms/step - loss: 151.5362 - val_loss: 164.5813
# Epoch 460/500
# 7/7 [==============================] - 0s 10ms/step - loss: 151.0103 - val_loss: 164.0429
# Epoch 461/500
# 7/7 [==============================] - 0s 7ms/step - loss: 150.4821 - val_loss: 163.5038
# Epoch 462/500
# 7/7 [==============================] - 0s 7ms/step - loss: 149.9742 - val_loss: 162.9571
# Epoch 463/500
# 7/7 [==============================] - 0s 7ms/step - loss: 149.4488 - val_loss: 162.4198
# Epoch 464/500
# 7/7 [==============================] - 0s 8ms/step - loss: 148.9275 - val_loss: 161.8867
# Epoch 465/500
# 7/7 [==============================] - 0s 7ms/step - loss: 148.4129 - val_loss: 161.3427
# Epoch 466/500
# 7/7 [==============================] - 0s 7ms/step - loss: 147.8862 - val_loss: 160.8080
# Epoch 467/500
# 7/7 [==============================] - 0s 14ms/step - loss: 147.3802 - val_loss: 160.2713
# Epoch 468/500
# 7/7 [==============================] - 0s 10ms/step - loss: 146.8728 - val_loss: 159.7289
# Epoch 469/500
# 7/7 [==============================] - 0s 7ms/step - loss: 146.3528 - val_loss: 159.2071
# Epoch 470/500
# 7/7 [==============================] - 0s 7ms/step - loss: 145.8321 - val_loss: 158.6793
# Epoch 471/500
# 7/7 [==============================] - 0s 7ms/step - loss: 145.3246 - val_loss: 158.1500
# Epoch 472/500
# 7/7 [==============================] - 0s 8ms/step - loss: 144.8143 - val_loss: 157.6246
# Epoch 473/500
# 7/7 [==============================] - 0s 7ms/step - loss: 144.3108 - val_loss: 157.0925
# Epoch 474/500
# 7/7 [==============================] - 0s 7ms/step - loss: 143.8120 - val_loss: 156.5741
# Epoch 475/500
# 7/7 [==============================] - 0s 8ms/step - loss: 143.3006 - val_loss: 156.0495
# Epoch 476/500
# 7/7 [==============================] - 0s 7ms/step - loss: 142.8008 - val_loss: 155.5150
# Epoch 477/500
# 7/7 [==============================] - 0s 9ms/step - loss: 142.2914 - val_loss: 154.9945
# Epoch 478/500
# 7/7 [==============================] - 0s 7ms/step - loss: 141.7939 - val_loss: 154.4810
# Epoch 479/500
# 7/7 [==============================] - 0s 7ms/step - loss: 141.2890 - val_loss: 153.9635
# Epoch 480/500
# 7/7 [==============================] - 0s 7ms/step - loss: 140.7902 - val_loss: 153.4441
# Epoch 481/500
# 7/7 [==============================] - 0s 7ms/step - loss: 140.2970 - val_loss: 152.9279
# Epoch 482/500
# 7/7 [==============================] - 0s 13ms/step - loss: 139.8134 - val_loss: 152.3929
# Epoch 483/500
# 7/7 [==============================] - 0s 10ms/step - loss: 139.3038 - val_loss: 151.8831
# Epoch 484/500
# 7/7 [==============================] - 0s 7ms/step - loss: 138.8132 - val_loss: 151.3739
# Epoch 485/500
# 7/7 [==============================] - 0s 7ms/step - loss: 138.3140 - val_loss: 150.8607
# Epoch 486/500
# 7/7 [==============================] - 0s 7ms/step - loss: 137.8235 - val_loss: 150.3420
# Epoch 487/500
# 7/7 [==============================] - 0s 7ms/step - loss: 137.3323 - val_loss: 149.8372
# Epoch 488/500
# 7/7 [==============================] - 0s 7ms/step - loss: 136.8385 - val_loss: 149.3376
# Epoch 489/500
# 7/7 [==============================] - 0s 8ms/step - loss: 136.3480 - val_loss: 148.8278
# Epoch 490/500
# 7/7 [==============================] - 0s 7ms/step - loss: 135.8689 - val_loss: 148.3322
# Epoch 491/500
# 7/7 [==============================] - 0s 9ms/step - loss: 135.3770 - val_loss: 147.8238
# Epoch 492/500
# 7/7 [==============================] - 0s 8ms/step - loss: 134.8906 - val_loss: 147.3152
# Epoch 493/500
# 7/7 [==============================] - 0s 7ms/step - loss: 134.4148 - val_loss: 146.8083
# Epoch 494/500
# 7/7 [==============================] - 0s 8ms/step - loss: 133.9366 - val_loss: 146.3005
# Epoch 495/500
# 7/7 [==============================] - 0s 7ms/step - loss: 133.4537 - val_loss: 145.8033
# Epoch 496/500
# 7/7 [==============================] - 0s 18ms/step - loss: 132.9834 - val_loss: 145.2950
# Epoch 497/500
# 7/7 [==============================] - 0s 8ms/step - loss: 132.4917 - val_loss: 144.8057
# Epoch 498/500
# 7/7 [==============================] - 0s 10ms/step - loss: 132.0168 - val_loss: 144.3151
# Epoch 499/500
# 7/7 [==============================] - 0s 7ms/step - loss: 131.5413 - val_loss: 143.8166
# Epoch 500/500
# 7/7 [==============================] - 0s 7ms/step - loss: 131.0650 - val_loss: 143.3224

# %%
plot_loss(history)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# linear_model = tf.keras.Sequential([
#     normalizer,
#     layers.Dense(units=1)
# ])
# linear_model.compile(
#     optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
#     loss='mean_squared_error')
#
# history = linear_model.fit(
#     train_features,
#     train_labels,
#     epochs=100,
#     # to view the logs, uncomment this:
#     verbose=0,
#     # validation split: 20% of the training data.
#     validation_split = 0.2)
#
# plot_loss(history)
# ```
#
# </details>

# %% [markdown]
# Predict the output values of the test set, and compute the RMSE.

# %%
# Write your solution here
test_predictions = model.predict(test_features)
mse = metrics.mean_squared_error(test_labels, test_predictions)
print(np.sqrt(mse))
# Out:
# 3/3 [==============================] - 0s 3ms/step
# 11.544761320254809

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# y_pred= linear_model.predict(test_features)
# print(np.sqrt(metrics.mean_squared_error(test_labels, y_pred)))
# ```
#
# </details>

# %% [markdown]
# ## Authors

# %% [markdown]
# [Kopal Garg](https://www.linkedin.com/in/gargkopal/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01) is a Data Scientist Intern at IBM, and a Masters student in Computer Science at the University of Toronto.

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2022-07-06|0.1|Kopal|Create Lab||2022-08-09|0.2|Steve H.|QA pass|

# %% [markdown]
# Copyright © 2022 IBM Corporation. All rights reserved.
